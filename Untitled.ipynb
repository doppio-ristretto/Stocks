# %%
import requests
import json 
key = '71H6VN2GGMWU3MAU'
ticker = 'CVS'
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={}&apikey={}'.format(ticker, key)
response = requests.get(url)
print(response.json())
# Out:
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend Events', '2. Symbol': 'CVS', '3. Last Refreshed': '2020-11-02', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2020-11-02': {'1. open': '56.8700', '2. high': '58.2300', '3. low': '56.1897', '4. close': '58.0800', '5. adjusted close': '58.0800', '6. volume': '9437916', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-30': {'1. open': '55.9300', '2. high': '56.3050', '3. low': '55.4000', '4. close': '56.0900', '5. adjusted close': '56.0900', '6. volume': '8665545', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-29': {'1. open': '56.4600', '2. high': '56.6700', '3. low': '55.3600', '4. close': '55.9300', '5. adjusted close': '55.9300', '6. volume': '9757946', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-28': {'1. open': '57.3600', '2. high': '57.9400', '3. low': '56.4400', '4. close': '56.5700', '5. adjusted close': '56.5700', '6. volume': '10660215', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-27': {'1. open': '59.1200', '2. high': '59.2640', '3. low': '58.1100', '4. close': '58.1500', '5. adjusted close': '58.1500', '6. volume': '5415021', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-26': {'1. open': '59.9100', '2. high': '59.9800', '3. low': '58.6700', '4. close': '59.5600', '5. adjusted close': '59.5600', '6. volume': '7551482', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-23': {'1. open': '59.7800', '2. high': '60.6000', '3. low': '59.6900', '4. close': '60.2500', '5. adjusted close': '60.2500', '6. volume': '6810115', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-22': {'1. open': '59.1400', '2. high': '59.5250', '3. low': '58.6243', '4. close': '59.4800', '5. adjusted close': '59.4800', '6. volume': '5724113', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-21': {'1. open': '58.6200', '2. high': '59.6200', '3. low': '58.6100', '4. close': '59.2300', '5. adjusted close': '59.2300', '6. volume': '5385324', '7. dividend amount': '0.5000', '8. split coefficient': '1.0'}, '2020-10-20': {'1. open': '59.0400', '2. high': '59.8650', '3. low': '58.4600', '4. close': '59.4300', '5. adjusted close': '58.9325', '6. volume': '7590649', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-19': {'1. open': '60.0600', '2. high': '60.4400', '3. low': '58.7100', '4. close': '58.7800', '5. adjusted close': '58.2880', '6. volume': '6983876', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-16': {'1. open': '59.3700', '2. high': '59.8600', '3. low': '58.9000', '4. close': '59.5900', '5. adjusted close': '59.0912', '6. volume': '6822607', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-15': {'1. open': '58.0800', '2. high': '59.3300', '3. low': '57.9100', '4. close': '59.3200', '5. adjusted close': '58.8234', '6. volume': '8208656', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-14': {'1. open': '58.9400', '2. high': '59.3400', '3. low': '58.4400', '4. close': '58.5100', '5. adjusted close': '58.0202', '6. volume': '6193746', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-13': {'1. open': '59.4000', '2. high': '59.9500', '3. low': '58.9500', '4. close': '59.1200', '5. adjusted close': '58.6251', '6. volume': '5700153', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-12': {'1. open': '59.5000', '2. high': '60.2200', '3. low': '59.2717', '4. close': '59.7200', '5. adjusted close': '59.2201', '6. volume': '5806887', '7. dividend amount': '0.0000', '8. split coefficient': '1.0'}, '2020-10-09': {'1. open': '60.8000', '2. high': '60.8000', '3. low': '59.2100', '4. close': '59.4000', '5. adjusted close': '58.9028', '6. volume': '5698910', '7. dividend amount': '0.0000', '8. split coeff ...

# %%
import requests
import json 
key = '71H6VN2GGMWU3MAU'
ticker = 'CVS'
url = 'https://www.alphavantage.co/query?function=OVERVIEW&symbol=IBM&apikey=demo'
response = requests.get(url)
print(response.json())
# Out:
# {'Symbol': 'IBM', 'AssetType': 'Common Stock', 'Name': 'International Business Machines Corporation', 'Description': "International Business Machines Corporation operates as an integrated solutions and services company worldwide. Its Cloud & Cognitive Software segment offers software for vertical and domain-specific solutions in health, financial services, and Internet of Things (IoT), weather, and security software and services application areas; and customer information control system and storage, and analytics and integration software solutions to support client mission critical on-premise workloads in banking, airline, and retail industries. It also offers middleware and data platform software, including Red Hat, which enables the operation of clients' hybrid multi-cloud environments; and Cloud Paks, WebSphere distributed, and analytics platform software, such as DB2 distributed, information integration, and enterprise content management, as well as IoT, Blockchain and AI/Watson platforms. The company's Global Business Services segment offers business consulting services; system integration, application management, maintenance, and support services for packaged software; finance, procurement, talent and engagement, industry-specific business process outsourcing services; IT infrastructure and platform services. Its Global Technology Services segment provides project, managed, outsourcing, and cloud-delivered services for enterprise IT infrastructure environments; and IT infrastructure support services. It's Systems segment offers servers for businesses, cloud service providers, and scientific computing organizations; data storage products and solutions; and z/OS, an enterprise operating system, as well as Linux. Its Global Financing segment provides lease, installment payment, loan financing, short-term working capital financing, and remanufacturing and remarketing services. It was formerly known as Computing-Tabulating-Recording Co. and changed its name to International Business Machines Corporation in 1924. It was founded in 1911 and is headquartered in Armonk, New York.", 'Exchange': 'NYSE', 'Currency': 'USD', 'Country': 'USA', 'Sector': 'Technology', 'Industry': 'Information Technology Services', 'Address': 'One New Orchard Road, Armonk, NY, United States, 10504', 'FullTimeEmployees': '352600', 'FiscalYearEnd': 'December', 'LatestQuarter': '2020-09-30', 'MarketCapitalization': '100333019136', 'EBITDA': '15690000384', 'PERatio': '12.0781', 'PEGRatio': '7.0589', 'BookValue': '23.801', 'DividendPerShare': '6.52', 'DividendYield': '0.0584', 'EPS': '8.823', 'RevenuePerShareTTM': '84.402', 'ProfitMargin': '0.1053', 'OperatingMarginTTM': '0.1205', 'ReturnOnAssetsTTM': '0.0372', 'ReturnOnEquityTTM': '0.401', 'RevenueTTM': '75030003712', 'GrossProfitTTM': '36489000000', 'DilutedEPSTTM': '8.823', 'QuarterlyEarningsGrowthYOY': '0.011', 'QuarterlyRevenueGrowthYOY': '-0.026', 'AnalystTargetPrice': '135.93', 'TrailingPE': '12.0781', 'ForwardPE': '9.1075', 'PriceToSalesRatioTTM': '1.2726', 'PriceToBookRatio': '4.4809', 'EVToRevenue': '1.9969', 'EVToEBITDA': '9.7848', 'Beta': '1.1572', '52WeekHigh': '158.75', '52WeekLow': '90.56', '50DayMovingAverage': '120.4334', '200DayMovingAverage': '122.4258', 'SharesOutstanding': '891057024', 'SharesFloat': '889649246', 'SharesShort': '22921703', 'SharesShortPriorMonth': '22132531', 'ShortRatio': '4.81', 'ShortPercentOutstanding': '0.03', 'ShortPercentFloat': '0.0258', 'PercentInsiders': '0.108', 'PercentInstitutions': '58.555', 'ForwardAnnualDividendRate': '6.52', 'ForwardAnnualDividendYield': '0.0584', 'PayoutRatio': '0.6129', 'DividendDate': '2020-12-10', 'ExDividendDate': '2020-11-09', 'LastSplitFactor': '2:1', 'LastSplitDate': '1999-05-27'}
